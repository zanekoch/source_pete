# %%
import pandas as pd 
import numpy as np 
import sys
import os
import glob
import seaborn as sns

# %%
fn = '/Users/vuthaiha/Desktop/window_hoff//diff_pete/roadmap/blood/chromHMM_posterior/val_E034/roc/tpr_fpr_all_states.txt.gz'
df = pd.read_csv(fn, index_col = 0, header = 0, sep = '\t')
ax = sns.lineplot(x='fpr_S1', y = 'tpr_S1', data = df)
df.head(10)
# Out:
#                     true_pos_num_S1  false_pos_num_S1  num_seg_true_S1  \
# score_greater_0.99                0                 0             3179
# score_greater_0.98                0                 0             3179
# score_greater_0.97                0                 0             3179
# score_greater_0.96                0                 0             3179
# score_greater_0.95                0                 0             3179
# score_greater_0.94                4                71             3179
# score_greater_0.93              990             15192             3179
# score_greater_0.92             1200             18195             3179
# score_greater_0.91             1349             20211             3179
# score_greater_0.9              1466             22250             3179
#
#                     num_seg_true_not_S1  num_seg_above_thres_S1  \
# score_greater_0.99             15178329                       0
# ...

# %%
fn = '/Users/vuthaiha/Desktop/window_hoff//diff_pete/roadmap/blood/baseline/val_E034/roc/tpr_fpr_all_states.txt.gz'
df = pd.read_csv(fn, index_col = 0, header = 0, sep = '\t')
ax = sns.lineplot(x='fpr_S1', y = 'tpr_S1', data = df)

# %%
fn = '/Users/vuthaiha/Desktop/window_hoff//diff_pete/roadmap/blood/multi_logistic/val_E034/roc/tpr_fpr_all_states.txt.gz'
df = pd.read_csv(fn, index_col = 0, header = 0, sep = '\t')
ax = sns.lineplot(x='fpr_S1', y = 'tpr_S1', data = df)
